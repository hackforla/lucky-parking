# %%
# Import modules
import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import gmaps
import pyproj
import googlemaps

# %%
gmaps_api_key =  ''
gmaps = googlemaps.Client(key=gmaps_api_key)

# %%
# Load Sampled Data
df=pd.read_csv("Simplified_Citation_After_2015July_to_2019.csv",low_memory=False)
df.head(5)
# Out:
#    Unnamed: 0  Ticket number              Issue Date  Issue time Meter Id  \
# 0          28     4361326712  2019/09/17 12:00:00 AM      1205.0      NaN
# 1         112     4361286823  2019/09/17 12:00:00 AM       853.0      NaN
# 2         224     4361159515  2019/09/17 12:00:00 AM       833.0      NaN
# 3         473     4361237226  2019/09/17 12:00:00 AM      1015.0      NaN
# 4         592     4360129196  2019/09/17 12:00:00 AM      1007.0      NaN
#
#    Marked Time RP State Plate  VIN  Make Body Style Color            Location  \
# 0          NaN             CA  NaN  TOYT         PA    GY    309 WINDWARD AVE
# 1          NaN             CA  NaN  TOYT         PA    WT       934 84TH ST W
# 2          NaN             CA  NaN  NISS         PA    WT   2601 MONMOUTH AVE
# 3          NaN             CA  NaN  HOND         PA    RD      615 HAMPTON DR
# 4          NaN             CA  NaN  VOLV         PA    SL  1346 MCCADDEN PL N
#
#    Route  Agency Violation code Violation Description  Fine amount  \
# 0  00163    51.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 1  00553    55.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 2  00536    55.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 3  00133    51.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 4  00487    54.0        80.69BS  NO PARK/STREET CLEAN         73.0
#
#        Latitude     Longitude
# 0  6.419487e+06  1.818861e+06
# 1  6.473690e+06  1.808839e+06
# 2  6.475329e+06  1.834194e+06
# 3  6.417752e+06  1.820642e+06
# 4  6.459495e+06  1.857205e+06

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Ticket number', 'Issue Date', 'Issue time', 'Meter Id',
#        'Marked Time', 'RP State Plate', 'VIN', 'Make', 'Body Style', 'Color',
#        'Location', 'Route', 'Agency', 'Violation code',
#        'Violation Description', 'Fine amount', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
# Identify bad Longitude/Latitude values
df['Longitude'].value_counts()
# Out:
# 9.999900e+04    11416
# 1.819688e+06       98
# 1.859071e+06       87
# 1.882602e+06       64
# 1.849114e+06       49
#                 ...
# 1.843271e+06        1
# 1.845315e+06        1
# 1.909664e+06        1
# 1.835485e+06        1
# 1.857892e+06        1
# Name: Longitude, Length: 50929, dtype: int64

# %%
# Check for null values
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# Ticket number                0
# Issue Date                   0
# Issue time                  15
# Meter Id                 65438
# Marked Time              84748
# RP State Plate               2
# VIN                      87554
# Make                        71
# Body Style                 115
# Color                       25
# Location                     2
# Route                      636
# Agency                       0
# Violation code               0
# Violation Description        5
# Fine amount                 52
# Latitude                     0
# Longitude                    0
# dtype: int64

# %%
# Remove null Location records
df = df[~df.Location.isnull()]

# %%
# Fraction of records with bad Lat/Lon values
len(df[(df['Latitude'] == 99999) | (df['Longitude'] == 99999)])/len(df)
# Out:
# 0.13036823830409358

# %%
# New dataset statistics
df[['Latitude', 'Longitude']].describe()
# Out:
#            Latitude     Longitude
# count  8.755200e+04  8.755200e+04
# mean   5.627169e+06  1.620580e+06
# std    2.140200e+06  5.893556e+05
# min    9.999900e+04  9.999900e+04
# 25%    6.423939e+06  1.826010e+06
# 50%    6.453559e+06  1.842360e+06
# 75%    6.475588e+06  1.858205e+06
# max    6.513150e+06  1.941866e+06

# %%
# Mask to work on good data first
mask = (df['Latitude'] != 99999) | (df['Longitude'] != 99999)
df[mask].head()
# Out:
#    Unnamed: 0  Ticket number              Issue Date  Issue time Meter Id  \
# 0          28     4361326712  2019/09/17 12:00:00 AM      1205.0      NaN
# 1         112     4361286823  2019/09/17 12:00:00 AM       853.0      NaN
# 2         224     4361159515  2019/09/17 12:00:00 AM       833.0      NaN
# 3         473     4361237226  2019/09/17 12:00:00 AM      1015.0      NaN
# 4         592     4360129196  2019/09/17 12:00:00 AM      1007.0      NaN
#
#    Marked Time RP State Plate  VIN  Make Body Style Color            Location  \
# 0          NaN             CA  NaN  TOYT         PA    GY    309 WINDWARD AVE
# 1          NaN             CA  NaN  TOYT         PA    WT       934 84TH ST W
# 2          NaN             CA  NaN  NISS         PA    WT   2601 MONMOUTH AVE
# 3          NaN             CA  NaN  HOND         PA    RD      615 HAMPTON DR
# 4          NaN             CA  NaN  VOLV         PA    SL  1346 MCCADDEN PL N
#
#    Route  Agency Violation code Violation Description  Fine amount  \
# 0  00163    51.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 1  00553    55.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 2  00536    55.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 3  00133    51.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 4  00487    54.0        80.69BS  NO PARK/STREET CLEAN         73.0
#
#        Latitude     Longitude
# 0  6.419487e+06  1.818861e+06
# 1  6.473690e+06  1.808839e+06
# 2  6.475329e+06  1.834194e+06
# 3  6.417752e+06  1.820642e+06
# 4  6.459495e+06  1.857205e+06

# %%
df.loc[mask,['Latitude','Longitude']].to_numpy()
# Out:
# array([[  33.9894116 , -118.4690242 ],
#        [  33.96243547, -118.29012558],
#        [  34.03212   , -118.284957  ],
#        ...,
#        [  33.96075103, -118.43936151],
#        [  33.95891498, -118.44837753],
#        [  34.03966412, -118.32245006]])

# %%
# Conversion using pyproj module
inProj = pyproj.Proj('epsg:2229', preserve_units=True) # make sure unit preserve 
outProj = pyproj.Proj('epsg:4326')
df.loc[mask,'Latitude'], df.loc[mask,'Longitude'] = pyproj.transform(inProj,outProj, df[mask]['Latitude'].values, df[mask]['Longitude'].values)

# %%
df[mask].head()
# Out:
#    Unnamed: 0  Ticket number              Issue Date  Issue time Meter Id  \
# 0          28     4361326712  2019/09/17 12:00:00 AM      1205.0      NaN
# 1         112     4361286823  2019/09/17 12:00:00 AM       853.0      NaN
# 2         224     4361159515  2019/09/17 12:00:00 AM       833.0      NaN
# 3         473     4361237226  2019/09/17 12:00:00 AM      1015.0      NaN
# 4         592     4360129196  2019/09/17 12:00:00 AM      1007.0      NaN
#
#    Marked Time RP State Plate  VIN  Make Body Style Color            Location  \
# 0          NaN             CA  NaN  TOYT         PA    GY    309 WINDWARD AVE
# 1          NaN             CA  NaN  TOYT         PA    WT       934 84TH ST W
# 2          NaN             CA  NaN  NISS         PA    WT   2601 MONMOUTH AVE
# 3          NaN             CA  NaN  HOND         PA    RD      615 HAMPTON DR
# 4          NaN             CA  NaN  VOLV         PA    SL  1346 MCCADDEN PL N
#
#    Route  Agency Violation code Violation Description  Fine amount   Latitude  \
# 0  00163    51.0        80.69BS  NO PARK/STREET CLEAN         73.0  27.195712
# 1  00553    55.0        80.69BS  NO PARK/STREET CLEAN         73.0  27.195712
# 2  00536    55.0        80.69BS  NO PARK/STREET CLEAN         73.0  27.195712
# 3  00133    51.0        80.69BS  NO PARK/STREET CLEAN         73.0  27.195712
# 4  00487    54.0        80.69BS  NO PARK/STREET CLEAN         73.0  27.195712
#
#     Longitude
# 0 -138.152012
# 1 -138.152012
# 2 -138.152012
# 3 -138.152012
# 4 -138.152012

# %%
def geocode_9s(location):
    result = gmaps.geocode('{}, Los Angeles, CA'.format(location))
    return result[0].get('geometry').get('location').get('lat'), result[0].get('geometry').get('location').get('lng')

# %%
df
# Out:
#        Unnamed: 0  Ticket number              Issue Date  Issue time Meter Id  \
# 0              28     4361326712  2019/09/17 12:00:00 AM      1205.0      NaN
# 1             112     4361286823  2019/09/17 12:00:00 AM       853.0      NaN
# 2             224     4361159515  2019/09/17 12:00:00 AM       833.0      NaN
# 3             473     4361237226  2019/09/17 12:00:00 AM      1015.0      NaN
# 4             592     4360129196  2019/09/17 12:00:00 AM      1007.0      NaN
# ...           ...            ...                     ...         ...      ...
# 87549     8705615     4262938105  2015/07/02 12:00:00 AM      1622.0    BH198
# 87550     8705782     4262766314  2015/07/02 12:00:00 AM      1302.0      NaN
# 87551     8705813     4262762140  2015/07/02 12:00:00 AM      1325.0      NaN
# 87552     8705825     4262762022  2015/07/02 12:00:00 AM      1256.0      NaN
# 87553     8706345     4262600580  2015/07/02 12:00:00 AM      1017.0      NaN
#
#        Marked Time RP State Plate  VIN  Make Body Style Color  \
# 0              NaN             CA  NaN  TOYT         PA    GY
# 1              NaN             CA  NaN  TOYT         PA    WT
# 2              NaN             CA  NaN  NISS         PA    WT
# 3              NaN             CA  NaN  HOND         PA    RD
# 4              NaN             CA  NaN  VOLV         PA    SL
# ...            ...            ...  ...   ...        ...   ...
# 87549          NaN             CA  NaN  NISS         PA    SL
# 87550          NaN             CA  NaN  CHEV         PA    GN
# 87551          NaN             CA  NaN  NISS         PA    BK
# 87552          NaN             CA  NaN  NISS         PA    BK
# 87553          NaN             CA  NaN  CHEV         PA    RD
#
#                     Location  Route  Agency Violation code  \
# 0           309 WINDWARD AVE  00163    51.0        80.69BS
# 1              934 84TH ST W  00553    55.0        80.69BS
# 2          2601 MONMOUTH AVE  00536    55.0        80.69BS
# 3             615 HAMPTON DR  00133    51.0        80.69BS
# 4         1346 MCCADDEN PL N  00487    54.0        80.69BS
# ...                      ...    ...     ...            ...
# 87549         200 BREED ST N  00602    56.0        88.13B+
# 87550       5306 VANTAGE AVE  00355    53.0        80.69BS
# 87551       8229 CALABAR AVE  00137    51.0        80.69BS
# 87552  R/O 203 CULVER BLVD E  00137    51.0       80.69AP+
# 87553           1925 5TH AVE  00171    51.0        80.69BS
#
#       Violation Description  Fine amount   Latitude   Longitude
# 0      NO PARK/STREET CLEAN         73.0  27.195712 -138.152012
# 1      NO PARK/STREET CLEAN         73.0  27.195712 -138.152012
# 2      NO PARK/STREET CLEAN         73.0  27.195712 -138.152012
# 3      NO PARK/STREET CLEAN         73.0  27.195712 -138.152012
# 4      NO PARK/STREET CLEAN         73.0  27.195712 -138.152012
# ...                     ...          ...        ...         ...
# 87549            METER EXP.         63.0  27.195712 -138.152012
# 87550  NO PARK/STREET CLEAN         73.0  27.195712 -138.152012
# 87551  NO PARK/STREET CLEAN         73.0  27.195712 -138.152012
# 87552      NO STOP/STANDING         93.0  27.195712 -138.152012
# 87553  NO PARK/STREET CLEAN         73.0  27.195712 -138.152012
#
# [87552 rows x 19 columns]

# %%
converted_lat, converted_lon = df.loc[~mask, 'Location'].apply(geocode_9s)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-160-5aa759eec058> in <module>
# ----> 1 converted_lat, converted_lon = df.loc[~mask, 'Location'].apply(geocode_9s)
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-159-fda0235365b0> in geocode_9s(location)
#       1 def geocode_9s(location):
# ----> 2     result = gmaps.geocode('{}, Los Angeles, CA'.format(location))
#       3     return result[0].get('geometry').get('location').get('lat'), result[0].get('geometry').get('location').get('lng')
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/googlemaps/client.py in wrapper(*args, **kwargs)
#     354     def wrapper(*args, **kwargs):
#     355         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 356         result = func(*args, **kwargs)
#     357         try:
#     358             del args[0]._extra_params
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/googlemaps/geocoding.py in geocode(client, address, components, bounds, region, language)
#      66         params["language"] = language
#      67
# ---> 68     return client._request("/maps/api/geocode/json", params)["results"]
#      69
#      70
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     227         try:
#     228             response = requests_method(base_url + authed_url,
# --> 229                                        **final_requests_kwargs)
#     230         except requests.exceptions.Timeout:
#     231             raise googlemaps.exceptions.Timeout()
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     541
#     542         kwargs.setdefault('allow_redirects', True)
# --> 543         return self.request('GET', url, **kwargs)
#     544
#     545     def options(self, url, **kwargs):
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# ~/anaconda3/envs/parking/lib/python3.7/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# ~/anaconda3/envs/parking/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~/anaconda3/envs/parking/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~/anaconda3/envs/parking/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     311     def recv_into(self, *args, **kwargs):
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#     315             if self.suppress_ragged_eofs and e.args == (-1, "Unexpected EOF"):
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1837             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1838         else:
# -> 1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# KeyboardInterrupt:

# %%
converted_lat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-162-e01d469edf65> in <module>
# ----> 1 converted_lat
#
# NameError: name 'converted_lat' is not defined

# %%
#picked 100000 samples since my computer cannot process more data than that 
gmaps.configure(api_key='') # type in your own API 
morning_time = (df["Issue time"] > 600) & (df["Issue time"] <= 1200) & (df.iloc[:100000]["Violation Description"] == "RED ZONE")
morning_time_df = df[morning_time][["Latitude_new","Longitude_new"]]

afternoon_time = (df["Issue time"] > 1200) & (df["Issue time"] <= 1800) & (df.iloc[:100000]["Violation Description"] == "RED ZONE")
afternoon_time_df = df[afternoon_time][["Latitude_new","Longitude_new"]]

evening_time = (df["Issue time"] > 1800)  & (df.iloc[:100000]["Violation Description"] == "RED ZONE")
evening_time_df = df[evening_time][["Latitude_new","Longitude_new"]]

fig = gmaps.figure()
morning_layer = gmaps.symbol_layer(morning_time_df, fill_color = "red", stroke_color = "red", scale = 1)
afternoon_layer = gmaps.symbol_layer(afternoon_time_df, fill_color = "green", stroke_color = "green", scale = 1)
evening_layer = gmaps.symbol_layer(evening_time_df, fill_color = "blue", stroke_color = "blue", scale = 1)
fig.add_layer(morning_layer)
fig.add_layer(afternoon_layer)
fig.add_layer(evening_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
df['Violation code'][df['Violation Description'] == 'NO PARK/STREET CLEAN'].value_counts()
# Out:
# 80.69BS    21208
# 8069BS       491
# Name: Violation code, dtype: int64

# %%
df['Violation Description'].unique()
# Out:
# array(['NO PARK/STREET CLEAN', 'EXCEED 72HRS-ST', 'RED ZONE',
#        'NO STOP/STAND', 'STANDNG IN ALLEY', 'DISPLAY OF PLATES',
#        'METER EXP.', 'DISPLAY OF TABS', 'PARKED ON SIDEWALK',
#        'FIRE HYDRANT', 'NO PARKING', 'WHITE ZONE', 'RESTRICTED TAXI ZONE',
#        'DISABLED PARKING/NO DP ID', 'NO STOPPING/ANTI-GRIDLOCK ZONE',
#        'PARKED OVER TIME LIMIT', 'NO STOP/STANDING',
#        'BLK BIKE PATH OR LANE', 'OUTSIDE LINES/METER',
#        'OVNIGHT PRK W/OUT PE', 'PREFERENTIAL PARKING', 'YELLOW ZONE',
#        'DOUBLE PARKING', 'PARKED IN BUS ZONE', 'HANDICAP/NO DP ID',
#        'STOP/STAND PROHIBIT', 'PARKED IN PARKWAY', '22514',
#        'BLOCKING DRIVEWAY', '18 IN. CURB/2 WAY',
#        'NO PARKING BETWEEN POSTED HOURS', 'PRIVATE PROPERTY',
#        'OFF STR MTR/OUT LINE', 'PARKED IN FIRE LANE',
#        'COMM TRAILER/22 FT.', 'DISABLED PARKING/BOUNDARIES',
#        'OFF STR/OVERTIME/MTR', 'DP-BLKNG ACCESS RAMP', 'PK OVERSIZ',
#        'CARSHARE PARKING', 'SAFETY ZONE/CURB', 'PARKING/FRONT YARD',
#        'PARKED IN CROSSWALK', 'COMM VEH OVER TIME LIMIT',
#        'CITY PARK/PROHIB', '18 IN/CURB/COMM VEH', 'GREEN ZONE',
#        'OVERNIGHT PARKING', '3 FT. SIDEWALK RAMP', '6344B', '21113A',
#        'PKD IN/ON PARKWAY', '22500E', 'NO EVIDENCE OF REG',
#        'DP- RO NOT PRESENT', 'NO STOPPING/STANDING',
#        'TIME LIMIT/CITY LOT', 'METER EXPIRED', 'SIGN POSTED - NO PARKING',
#        'PK IN PROH AREA', 'WITHIN INTERSECTION', '18 IN. CURB/1 WAY',
#        'PREF PARKING', 'STNDNG IN ALLEY', 'PK TRAILER', '22500F',
#        'EXPIRED TAGS', '22500H', '22502A', 'DISABLED PARKING/CROSS HATCH',
#        'PK VEH SALE/RNT', 'DSPLYPLATE A', '4000A', 'RED CURB',
#        'PARKING AREA', 'PK OTSD PSTD AR', 'LOAD/UNLOAD ONLY',
#        'WHITE CURB', 'HANDICPD/BLOCKING', 'NO STOP/STAND AM',
#        'PK OUTSD PK STL', '5200', 'NO PK BET 1-3AM', nan, '5204',
#        '22500B', '5201F', 'PARK IN GRID LOCK ZN', 'PKD OVER TIME LIMIT',
#        '57490884', 'HANDICAP/CROSS HATCH', 'PK OUTSD SPACE',
#        'BLOCK HANDICAP ACCES', 'RED FLAG DAY', 'NO STOP/STAND PM',
#        'DP-SUBPLATE', 'BLK BIKE PATH OR LAN', 'CLEANING VEH/STREET',
#        'PUBLIC GROUNDS', 'EXCEED TIME LMT', 'VIO-PERM/PARK', '2251157A',
#        'R/PRIV PARKING AREA', '8054', 'PARKING/FRONT YARD 1', '2251157B',
#        'PARKING UNHITCHED TR', '80581', '22500I', 'EXCEED 72 HOURS',
#        'WRG SD/NOT PRL', 'PARKING OUTSIDE PARKING STALLS',
#        'HANDICAP/ON LINE', '8502', '40001', '6344', 'RESTRICTED ZONE',
#        'COMVEH RES/OV TM LMT', '26708A1', '225078A2', '225078',
#        'DISABLED PARKING/OBSTRUCT ACCESS', 'COMVEH RES/OV TM B-2',
#        'COMVEH RES/OV TM C-3', 'STORING VEH/ON STR', '22502', '22500J',
#        'ABAND VEH/HIGHWAY', 'DP-REFUSE ID', 'PK OVERSIZED 3RD',
#        'OBST FIRE RD', 'ABAND VEH/PUB/PRIV', '22658A',
#        'PARKED OVER TIME LIM', 'NO STOPPING/ANTI-GRI',
#        'DISABLED PARKING/CRO', 'DISABLED PARKING/NO',
#        'COMM VEH OVER TIME L', 'NO PARKING BETWEEN P',
#        'DISABLED PARKING/OBS', 'PARK-PSTD AREAS', 'DSPLYPLATE B',
#        'OBSTR EXCAVATN', '17104h', 'DISABLED PARKING/BOU', '17104c',
#        '572521', '2251157C', 'OVERSIZED VEHICLE PA'], dtype=object)

# %%
df[df['Violation Description'] == 'CLEANING VEH/STREET']
# Out:
#        Unnamed: 0  Ticket number              Issue Date  Issue time Meter Id  \
# 17695     1753653     4338918846  2018/09/05 12:00:00 AM      1221.0      NaN
# 53686     5359303     4291389071  2017/01/13 12:00:00 AM       853.0      NaN
# 55191     5509385     4298738312  2016/12/19 12:00:00 AM      1103.0      NaN
#
#        Marked Time RP State Plate  VIN  Make Body Style Color  \
# 17695          NaN             CA  NaN  OTHR         PA    RD
# 53686          NaN             CA  NaN  HOND         PA    SL
# 55191          NaN             CA  NaN  FORD         CM    BK
#
#                Location  Route  Agency Violation code Violation Description  \
# 17695  980 MANZANITA ST  00446    54.0          80.74   CLEANING VEH/STREET
# 53686   14565 LANARK ST  00300    53.0          80.74   CLEANING VEH/STREET
# 55191   2626 ALSACE AVE  00531    55.0          80.74   CLEANING VEH/STREET
#
#        Fine amount   Latitude   Longitude
# 17695         53.0  34.090388 -118.282836
# 53686         53.0  34.217941 -118.450313
# 55191         53.0  34.032247 -118.355517

# %%
df[df['Violation code'] == '80.69BS']['Violation Description']
# Out:
# 0        NO PARK/STREET CLEAN
# 1        NO PARK/STREET CLEAN
# 2        NO PARK/STREET CLEAN
# 3        NO PARK/STREET CLEAN
# 4        NO PARK/STREET CLEAN
#                  ...
# 87537    NO PARK/STREET CLEAN
# 87548    NO PARK/STREET CLEAN
# 87550    NO PARK/STREET CLEAN
# 87551    NO PARK/STREET CLEAN
# 87553    NO PARK/STREET CLEAN
# Name: Violation Description, Length: 21208, dtype: object

# %%
df[df['Violation Description'] == 'NO PARK/STREET CLEAN']
# Out:
#        Unnamed: 0  Ticket number              Issue Date  Issue time Meter Id  \
# 0              28     4361326712  2019/09/17 12:00:00 AM      1205.0      NaN
# 1             112     4361286823  2019/09/17 12:00:00 AM       853.0      NaN
# 2             224     4361159515  2019/09/17 12:00:00 AM       833.0      NaN
# 3             473     4361237226  2019/09/17 12:00:00 AM      1015.0      NaN
# 4             592     4360129196  2019/09/17 12:00:00 AM      1007.0      NaN
# ...           ...            ...                     ...         ...      ...
# 87546     8705209     1111207742  2015/07/02 12:00:00 AM      1018.0      NaN
# 87548     8705581     4262972151  2015/07/02 12:00:00 AM      1010.0      NaN
# 87550     8705782     4262766314  2015/07/02 12:00:00 AM      1302.0      NaN
# 87551     8705813     4262762140  2015/07/02 12:00:00 AM      1325.0      NaN
# 87553     8706345     4262600580  2015/07/02 12:00:00 AM      1017.0      NaN
#
#        Marked Time RP State Plate  VIN  Make Body Style Color  \
# 0              NaN             CA  NaN  TOYT         PA    GY
# 1              NaN             CA  NaN  TOYT         PA    WT
# 2              NaN             CA  NaN  NISS         PA    WT
# 3              NaN             CA  NaN  HOND         PA    RD
# 4              NaN             CA  NaN  VOLV         PA    SL
# ...            ...            ...  ...   ...        ...   ...
# 87546          NaN             CA  NaN  NISS         PA    GY
# 87548          NaN             WA  NaN  CHEV         PA    RD
# 87550          NaN             CA  NaN  CHEV         PA    GN
# 87551          NaN             CA  NaN  NISS         PA    BK
# 87553          NaN             CA  NaN  CHEV         PA    RD
#
#                  Location  Route  Agency Violation code Violation Description  \
# 0        309 WINDWARD AVE  00163    51.0        80.69BS  NO PARK/STREET CLEAN
# 1           934 84TH ST W  00553    55.0        80.69BS  NO PARK/STREET CLEAN
# 2       2601 MONMOUTH AVE  00536    55.0        80.69BS  NO PARK/STREET CLEAN
# 3          615 HAMPTON DR  00133    51.0        80.69BS  NO PARK/STREET CLEAN
# 4      1346 MCCADDEN PL N  00487    54.0        80.69BS  NO PARK/STREET CLEAN
# ...                   ...    ...     ...            ...                   ...
# 87546     10717 LAWLER ST  00146    51.0         8069BS  NO PARK/STREET CLEAN
# 87548   4322 LEIMERT BLVD  00541    55.0        80.69BS  NO PARK/STREET CLEAN
# 87550    5306 VANTAGE AVE  00355    53.0        80.69BS  NO PARK/STREET CLEAN
# 87551    8229 CALABAR AVE  00137    51.0        80.69BS  NO PARK/STREET CLEAN
# 87553        1925 5TH AVE  00171    51.0        80.69BS  NO PARK/STREET CLEAN
#
#        Fine amount   Latitude   Longitude
# 0             73.0  33.989412 -118.469024
# 1             73.0  33.962435 -118.290126
# 2             73.0  34.032120 -118.284957
# 3             73.0  33.994284 -118.474775
# 4             73.0  34.095217 -118.337472
# ...            ...        ...         ...
# 87546         73.0  34.025129 -118.412452
# 87548         73.0  34.005806 -118.328999
# 87550         73.0  34.166789 -118.398139
# 87551         73.0  33.960751 -118.439362
# 87553         73.0  34.039664 -118.322450
#
# [21699 rows x 19 columns]

# %%
df[(df['Location'].str.contains('WINDWARD')) & (df['Violation Description'] == 'NO PARK/STREET CLEAN')]
# Out:
#        Unnamed: 0  Ticket number              Issue Date  Issue time Meter Id  \
# 0              28     4361326712  2019/09/17 12:00:00 AM      1205.0      NaN
# 1370       139182     4358481536  2019/07/22 12:00:00 AM      1140.0      NaN
# 2307       229728     4357259970  2019/07/01 12:00:00 AM      1110.0      NaN
# 6525       651005     4352300315  2019/04/09 12:00:00 AM      1200.0      NaN
# 7280       726282     4351612661  2019/03/26 12:00:00 AM      1111.0      NaN
# 8345       829154     4349764495  2019/03/05 12:00:00 AM      1109.0      NaN
# 16726     1659384     4340345590  2018/09/25 12:00:00 AM      1138.0      NaN
# 20207     2010426     4332648950  2018/07/17 12:00:00 AM      1231.0      NaN
# 22779     2270957     4333866143  2018/05/29 12:00:00 AM      1132.0      NaN
# 35531     3536292     4318915086  2017/10/30 12:00:00 AM      1140.0      NaN
# 42351     4216256     4312610864  2017/07/11 12:00:00 AM      1118.0      NaN
# 48124     4798941     4306059085  2017/04/11 12:00:00 AM      1107.0      NaN
# 48215     4809320     4306058842  2017/04/10 12:00:00 AM      1210.0      NaN
# 58012     5789257     4296511004  2016/11/01 12:00:00 AM      1106.0      NaN
# 59393     5919919     4295448942  2016/10/11 12:00:00 AM      1114.0      NaN
# 60772     6056214     4292409656  2016/09/20 12:00:00 AM      1108.0      NaN
# 61838     6159005     4291065704  2016/08/30 12:00:00 AM      1242.0      NaN
# 62815     6254068     4290979291  2016/08/15 12:00:00 AM      1105.0      NaN
# 66184     6585702     4285485466  2016/06/20 12:00:00 AM      1156.0      NaN
# 66942     6665372     4285456221  2016/06/06 12:00:00 AM      1222.0      NaN
# 68162     6786540     4283035890  2016/05/17 12:00:00 AM      1217.0      NaN
# 69994     6973023     4281672743  2016/04/18 12:00:00 AM      1105.0      NaN
# 75290     7482725     4275718296  2016/01/26 12:00:00 AM      1110.0      NaN
# 78686     7832050     4271931300  2015/11/24 12:00:00 AM      1117.0      NaN
# 82458     8203237     4267701034  2015/09/22 12:00:00 AM      1139.0      NaN
# 86104     8560824     4263557885  2015/07/27 12:00:00 AM      1202.0      NaN
#
#        Marked Time RP State Plate  VIN  Make Body Style Color  \
# 0              NaN             CA  NaN  TOYT         PA    GY
# 1370           NaN             AL  NaN  CADI         PA    BK
# 2307           NaN             NV  NaN  NISS         PA    RD
# 6525           NaN             CA  NaN  LEXS         PA    GY
# 7280           NaN             UT  NaN  HYUN         PA    BL
# 8345           NaN             CA  NaN  MAZD         PA    SL
# 16726          NaN             CA  NaN  SUBA         PA    BK
# 20207          NaN             CA  NaN  HOND         PA    WT
# 22779          NaN             CA  NaN  DODG         PA    SL
# 35531          NaN             CA  NaN  TOYT         PA    WT
# 42351          NaN             CA  NaN  DODG         PU    WT
# 48124          NaN             CA  NaN  HOND         PA    BL
# 48215          NaN             AZ  NaN  VOLK         PA    WT
# 58012          NaN             CA  NaN  TOYT         PA    SL
# 59393          NaN             NC  NaN  TOYT         PA    SL
# 60772          NaN             CA  NaN  JEEP         PA    BK
# 61838          NaN             CA  NaN  TOYT         PA    WT
# 62815          NaN             CA  NaN  TOYT         PA    WT
# 66184          NaN             CA  NaN  MERZ         PA    BK
# 66942          NaN             CA  NaN  VOLK         PA    WT
# 68162          NaN             CA  NaN  CADI         PA    SL
# 69994          NaN             CA  NaN  TOYT         PA    BK
# 75290          NaN             AZ  NaN  NISS         PA    GY
# 78686          NaN             AZ  NaN  HOND         PA    SL
# 82458          NaN             CA  NaN  DODG         VN    GN
# 86104          NaN             CA  NaN  CHEV         PA    RD
#
#                  Location  Route  Agency Violation code Violation Description  \
# 0        309 WINDWARD AVE  00163    51.0        80.69BS  NO PARK/STREET CLEAN
# 1370    77 WINDWARD AVE E   112R    51.0        80.69BS  NO PARK/STREET CLEAN
# 2307      69 WINDWARD AVE  00136    51.0        80.69BS  NO PARK/STREET CLEAN
# 6525      66 WINDWARD AVE  00135    51.0        80.69BS  NO PARK/STREET CLEAN
# 7280      64 WINDWARD AVE  00132    51.0        80.69BS  NO PARK/STREET CLEAN
# 8345      56 WINDWARD AVE  00132    51.0        80.69BS  NO PARK/STREET CLEAN
# 16726     56 WINDWARD AVE   161R    51.0        80.69BS  NO PARK/STREET CLEAN
# 20207    325 WINDWARD AVE  00134    51.0        80.69BS  NO PARK/STREET CLEAN
# 22779     36 WINDWARD AVE  00133    51.0        80.69BS  NO PARK/STREET CLEAN
# 35531     23 WINDWARD AVE  00135    51.0        80.69BS  NO PARK/STREET CLEAN
# 42351     66 WINDWARD AVE   139B    51.0        80.69BS  NO PARK/STREET CLEAN
# 48124  32 WINDWARD AVENUE  00132    51.0        80.69BS  NO PARK/STREET CLEAN
# 48215  69 WINDWARD AVENUE  00132    51.0        80.69BS  NO PARK/STREET CLEAN
# 58012     46 WINDWARD AVE  00135    51.0        80.69BS  NO PARK/STREET CLEAN
# 59393     40 WINDWARD AVE  138R2    51.0        80.69BS  NO PARK/STREET CLEAN
# 60772     52 WINDWARD AVE  138R2    51.0        80.69BS  NO PARK/STREET CLEAN
# 61838  40 WINDWARD AVENUE  00906    51.0        80.69BS  NO PARK/STREET CLEAN
# 62815     77 WINDWARD AVE  138R2    51.0        80.69BS  NO PARK/STREET CLEAN
# 66184  29 WINDWARD AVENUE   906R    51.0        80.69BS  NO PARK/STREET CLEAN
# 66942    221 WINDWARD AVE  00135    51.0        80.69BS  NO PARK/STREET CLEAN
# 68162    311 WINDWARD AVE  00163    51.0        80.69BS  NO PARK/STREET CLEAN
# 69994     23 WINDWARD AVE  00135    51.0        80.69BS  NO PARK/STREET CLEAN
# 75290  54 WINDWARD AVENUE  00134    51.0        80.69BS  NO PARK/STREET CLEAN
# 78686   46 WINDWARD AVE E  00134    51.0        80.69BS  NO PARK/STREET CLEAN
# 82458   20 WINDWARD AVE E  00134    51.0        80.69BS  NO PARK/STREET CLEAN
# 86104   79 WINDWARD AVE E  00136    51.0        80.69BS  NO PARK/STREET CLEAN
#
#        Fine amount   Latitude   Longitude
# 0             73.0  33.989412 -118.469024
# 1370          73.0  33.987515 -118.472533
# 2307          73.0  33.987456 -118.472630
# 6525          73.0  33.987435 -118.472664
# 7280          73.0  33.987420 -118.472689
# 8345          73.0  33.987359 -118.472788
# 16726         73.0  33.987359 -118.472788
# 20207         73.0  33.989715 -118.468564
# 22779         73.0  33.987207 -118.473037
# 35531         73.0  33.987115 -118.473187
# 42351         73.0  33.987435 -118.472664
# 48124         73.0  33.987176 -118.473087
# 48215         73.0  33.987456 -118.472630
# 58012         73.0  33.987283 -118.472913
# 59393         73.0  33.987237 -118.472987
# 60772         73.0  33.987328 -118.472838
# 61838         73.0  33.987237 -118.472987
# 62815         73.0  33.987515 -118.472533
# 66184         73.0  33.987159 -118.473115
# 66942         73.0  33.988525 -118.470372
# 68162         73.0  33.989454 -118.468961
# 69994         73.0  33.987115 -118.473187
# 75290         73.0  33.987344 -118.472813
# 78686         73.0  33.987283 -118.472913
# 82458         73.0  33.987085 -118.473236
# 86104         73.0  33.987530 -118.472509

# %%
pd.Timestamp(df.loc[0, 'Issue Date'])
# Out:
# Timestamp('2019-09-17 00:00:00')

# %%
df.loc[:,'Issue Date'] = df['Issue Date'].apply(pd.Timestamp)

# %%
df
# Out:
#        Unnamed: 0  Ticket number Issue Date  Issue time Meter Id  Marked Time  \
# 0              28     4361326712 2019-09-17      1205.0      NaN          NaN
# 1             112     4361286823 2019-09-17       853.0      NaN          NaN
# 2             224     4361159515 2019-09-17       833.0      NaN          NaN
# 3             473     4361237226 2019-09-17      1015.0      NaN          NaN
# 4             592     4360129196 2019-09-17      1007.0      NaN          NaN
# ...           ...            ...        ...         ...      ...          ...
# 87549     8705615     4262938105 2015-07-02      1622.0    BH198          NaN
# 87550     8705782     4262766314 2015-07-02      1302.0      NaN          NaN
# 87551     8705813     4262762140 2015-07-02      1325.0      NaN          NaN
# 87552     8705825     4262762022 2015-07-02      1256.0      NaN          NaN
# 87553     8706345     4262600580 2015-07-02      1017.0      NaN          NaN
#
#       RP State Plate  VIN  Make Body Style Color               Location  \
# 0                 CA  NaN  TOYT         PA    GY       309 WINDWARD AVE
# 1                 CA  NaN  TOYT         PA    WT          934 84TH ST W
# 2                 CA  NaN  NISS         PA    WT      2601 MONMOUTH AVE
# 3                 CA  NaN  HOND         PA    RD         615 HAMPTON DR
# 4                 CA  NaN  VOLV         PA    SL     1346 MCCADDEN PL N
# ...              ...  ...   ...        ...   ...                    ...
# 87549             CA  NaN  NISS         PA    SL         200 BREED ST N
# 87550             CA  NaN  CHEV         PA    GN       5306 VANTAGE AVE
# 87551             CA  NaN  NISS         PA    BK       8229 CALABAR AVE
# 87552             CA  NaN  NISS         PA    BK  R/O 203 CULVER BLVD E
# 87553             CA  NaN  CHEV         PA    RD           1925 5TH AVE
#
#        Route  Agency Violation code Violation Description  Fine amount  \
# 0      00163    51.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 1      00553    55.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 2      00536    55.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 3      00133    51.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 4      00487    54.0        80.69BS  NO PARK/STREET CLEAN         73.0
# ...      ...     ...            ...                   ...          ...
# 87549  00602    56.0        88.13B+            METER EXP.         63.0
# 87550  00355    53.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 87551  00137    51.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 87552  00137    51.0       80.69AP+      NO STOP/STANDING         93.0
# 87553  00171    51.0        80.69BS  NO PARK/STREET CLEAN         73.0
#
#         Latitude   Longitude
# 0      33.989412 -118.469024
# 1      33.962435 -118.290126
# 2      34.032120 -118.284957
# 3      33.994284 -118.474775
# 4      34.095217 -118.337472
# ...          ...         ...
# 87549  34.042926 -118.211886
# 87550  34.166789 -118.398139
# 87551  33.960751 -118.439362
# 87552  33.958915 -118.448378
# 87553  34.039664 -118.322450
#
# [76138 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76138 entries, 0 to 87553
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             76138 non-null  int64
#  1   Ticket number          76138 non-null  int64
#  2   Issue Date             76138 non-null  datetime64[ns]
#  3   Issue time             76127 non-null  float64
#  4   Meter Id               21218 non-null  object
#  5   Marked Time            2556 non-null   float64
#  6   RP State Plate         76137 non-null  object
#  7   VIN                    0 non-null      float64
#  8   Make                   76107 non-null  object
#  9   Body Style             76098 non-null  object
#  10  Color                  76126 non-null  object
#  11  Location               76138 non-null  object
#  12  Route                  75807 non-null  object
#  13  Agency                 76138 non-null  float64
#  14  Violation code         76138 non-null  object
#  15  Violation Description  76136 non-null  object
#  16  Fine amount            76115 non-null  float64
#  17  Latitude               76138 non-null  float64
#  18  Longitude              76138 non-null  float64
# dtypes: datetime64[ns](1), float64(7), int64(2), object(9)
# memory usage: 14.1+ MB

# %%
df['Issue Date'].apply(lambda x: x.dayofweek)
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 87549    3
# 87550    3
# 87551    3
# 87552    3
# 87553    3
# Name: Issue Date, Length: 76138, dtype: int64

# %%
df.loc[:,'Day of Week'] = df['Issue Date'].apply(lambda x: x.dayofweek)

# %%
df
# Out:
#        Unnamed: 0  Ticket number Issue Date  Issue time Meter Id  Marked Time  \
# 0              28     4361326712 2019-09-17      1205.0      NaN          NaN
# 1             112     4361286823 2019-09-17       853.0      NaN          NaN
# 2             224     4361159515 2019-09-17       833.0      NaN          NaN
# 3             473     4361237226 2019-09-17      1015.0      NaN          NaN
# 4             592     4360129196 2019-09-17      1007.0      NaN          NaN
# ...           ...            ...        ...         ...      ...          ...
# 87549     8705615     4262938105 2015-07-02      1622.0    BH198          NaN
# 87550     8705782     4262766314 2015-07-02      1302.0      NaN          NaN
# 87551     8705813     4262762140 2015-07-02      1325.0      NaN          NaN
# 87552     8705825     4262762022 2015-07-02      1256.0      NaN          NaN
# 87553     8706345     4262600580 2015-07-02      1017.0      NaN          NaN
#
#       RP State Plate  VIN  Make Body Style Color               Location  \
# 0                 CA  NaN  TOYT         PA    GY       309 WINDWARD AVE
# 1                 CA  NaN  TOYT         PA    WT          934 84TH ST W
# 2                 CA  NaN  NISS         PA    WT      2601 MONMOUTH AVE
# 3                 CA  NaN  HOND         PA    RD         615 HAMPTON DR
# 4                 CA  NaN  VOLV         PA    SL     1346 MCCADDEN PL N
# ...              ...  ...   ...        ...   ...                    ...
# 87549             CA  NaN  NISS         PA    SL         200 BREED ST N
# 87550             CA  NaN  CHEV         PA    GN       5306 VANTAGE AVE
# 87551             CA  NaN  NISS         PA    BK       8229 CALABAR AVE
# 87552             CA  NaN  NISS         PA    BK  R/O 203 CULVER BLVD E
# 87553             CA  NaN  CHEV         PA    RD           1925 5TH AVE
#
#        Route  Agency Violation code Violation Description  Fine amount  \
# 0      00163    51.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 1      00553    55.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 2      00536    55.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 3      00133    51.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 4      00487    54.0        80.69BS  NO PARK/STREET CLEAN         73.0
# ...      ...     ...            ...                   ...          ...
# 87549  00602    56.0        88.13B+            METER EXP.         63.0
# 87550  00355    53.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 87551  00137    51.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 87552  00137    51.0       80.69AP+      NO STOP/STANDING         93.0
# 87553  00171    51.0        80.69BS  NO PARK/STREET CLEAN         73.0
#
#         Latitude   Longitude  Day of Week
# 0      33.989412 -118.469024            1
# 1      33.962435 -118.290126            1
# 2      34.032120 -118.284957            1
# 3      33.994284 -118.474775            1
# 4      34.095217 -118.337472            1
# ...          ...         ...          ...
# 87549  34.042926 -118.211886            3
# 87550  34.166789 -118.398139            3
# 87551  33.960751 -118.439362            3
# 87552  33.958915 -118.448378            3
# 87553  34.039664 -118.322450            3
#
# [76138 rows x 20 columns]

# %%
week_names = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
week_names_dict = {index: name for index, name in enumerate(week_names)}

# %%
week_names_dict
# Out:
# {0: 'Monday',
#  1: 'Tuesday',
#  2: 'Wednesday',
#  3: 'Thursday',
#  4: 'Friday',
#  5: 'Saturday',
#  6: 'Sunday'}

# %%
df.loc[:,'Day of Week'] = df['Day of Week'].replace(week_names_dict)

# %%
df
# Out:
#        Unnamed: 0  Ticket number Issue Date  Issue time Meter Id  Marked Time  \
# 0              28     4361326712 2019-09-17      1205.0      NaN          NaN
# 1             112     4361286823 2019-09-17       853.0      NaN          NaN
# 2             224     4361159515 2019-09-17       833.0      NaN          NaN
# 3             473     4361237226 2019-09-17      1015.0      NaN          NaN
# 4             592     4360129196 2019-09-17      1007.0      NaN          NaN
# ...           ...            ...        ...         ...      ...          ...
# 87549     8705615     4262938105 2015-07-02      1622.0    BH198          NaN
# 87550     8705782     4262766314 2015-07-02      1302.0      NaN          NaN
# 87551     8705813     4262762140 2015-07-02      1325.0      NaN          NaN
# 87552     8705825     4262762022 2015-07-02      1256.0      NaN          NaN
# 87553     8706345     4262600580 2015-07-02      1017.0      NaN          NaN
#
#       RP State Plate  VIN  Make Body Style Color               Location  \
# 0                 CA  NaN  TOYT         PA    GY       309 WINDWARD AVE
# 1                 CA  NaN  TOYT         PA    WT          934 84TH ST W
# 2                 CA  NaN  NISS         PA    WT      2601 MONMOUTH AVE
# 3                 CA  NaN  HOND         PA    RD         615 HAMPTON DR
# 4                 CA  NaN  VOLV         PA    SL     1346 MCCADDEN PL N
# ...              ...  ...   ...        ...   ...                    ...
# 87549             CA  NaN  NISS         PA    SL         200 BREED ST N
# 87550             CA  NaN  CHEV         PA    GN       5306 VANTAGE AVE
# 87551             CA  NaN  NISS         PA    BK       8229 CALABAR AVE
# 87552             CA  NaN  NISS         PA    BK  R/O 203 CULVER BLVD E
# 87553             CA  NaN  CHEV         PA    RD           1925 5TH AVE
#
#        Route  Agency Violation code Violation Description  Fine amount  \
# 0      00163    51.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 1      00553    55.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 2      00536    55.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 3      00133    51.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 4      00487    54.0        80.69BS  NO PARK/STREET CLEAN         73.0
# ...      ...     ...            ...                   ...          ...
# 87549  00602    56.0        88.13B+            METER EXP.         63.0
# 87550  00355    53.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 87551  00137    51.0        80.69BS  NO PARK/STREET CLEAN         73.0
# 87552  00137    51.0       80.69AP+      NO STOP/STANDING         93.0
# 87553  00171    51.0        80.69BS  NO PARK/STREET CLEAN         73.0
#
#         Latitude   Longitude Day of Week
# 0      33.989412 -118.469024     Tuesday
# 1      33.962435 -118.290126     Tuesday
# 2      34.032120 -118.284957     Tuesday
# 3      33.994284 -118.474775     Tuesday
# 4      34.095217 -118.337472     Tuesday
# ...          ...         ...         ...
# 87549  34.042926 -118.211886    Thursday
# 87550  34.166789 -118.398139    Thursday
# 87551  33.960751 -118.439362    Thursday
# 87552  33.958915 -118.448378    Thursday
# 87553  34.039664 -118.322450    Thursday
#
# [76138 rows x 20 columns]

# %%
def nearby_coords(df, lat, lon, radius=0.0001, st_clean_only=True):
    try:
        if st_clean_only:
            return df[df['Latitude'].between(lat-radius, lat+radius) & df['Longitude']
                      .between(lon-radius, lon+radius) & (df['Violation Description'] == 'NO PARK/STREET CLEAN')]
        else:
            return df[df['Latitude'].between(lat-radius, lat+radius) & df['Longitude'].between(lon-radius, lon+radius)]
    except:
        return

# %%
def nearby_coords(df, lat, lon, radius=0.0001, st_clean_only=True):
    if st_clean_only:
        return df[df['Latitude'].between(lat-radius, lat+radius) & df['Longitude']
                  .between(lon-radius, lon+radius) & (df['Violation Description'] == 'NO PARK/STREET CLEAN')]
    else:
        return df[df['Latitude'].between(lat-radius, lat+radius) & df['Longitude'].between(lon-radius, lon+radius)]

# %%
nearby_coords(df, 34.039664,-118.322450, 0.002)
# Out:
#        Unnamed: 0  Ticket number Issue Date  Issue time Meter Id  Marked Time  \
# 24231     2415443     4331631043 2018-05-03      1052.0      NaN          NaN
# 36198     3601480     4318561332 2017-10-19       832.0      NaN          NaN
# 36199     3601481     4318561321 2017-10-19       828.0      NaN          NaN
# 44906     4471143     4310082442 2017-05-31      1041.0      NaN          NaN
# 78314     7796016     4272088726 2015-12-02      1010.0      NaN          NaN
# 87553     8706345     4262600580 2015-07-02      1017.0      NaN          NaN
#
#       RP State Plate  VIN  Make Body Style Color         Location  Route  \
# 24231             AZ  NaN  FORD         TK    WT   3615 21ST ST W  00143
# 36198             NV  NaN  NISS         PA    GY     1823 4TH AVE  00147
# 36199             CA  NaN  NISS         PA    RD     1726 5TH AVE  00147
# 44906             AL  NaN  NISS         PA    WT  2025 6TH AVENUE  00143
# 78314             GA  NaN  CHEV         PA    GY     2000 4TH AVE  00185
# 87553             CA  NaN  CHEV         PA    RD     1925 5TH AVE  00171
#
#        Agency Violation code Violation Description  Fine amount   Latitude  \
# 24231    51.0        80.69BS  NO PARK/STREET CLEAN         73.0  34.037979
# 36198    51.0        80.69BS  NO PARK/STREET CLEAN         73.0  34.040634
# 36199    51.0        80.69BS  NO PARK/STREET CLEAN         73.0  34.041558
# 44906    51.0        80.69BS  NO PARK/STREET CLEAN         73.0  34.038695
# 78314    51.0        80.69BS  NO PARK/STREET CLEAN         73.0  34.038934
# 87553    51.0        80.69BS  NO PARK/STREET CLEAN         73.0  34.039664
#
#         Longitude Day of Week
# 24231 -118.323801    Thursday
# 36198 -118.321266    Thursday
# 36199 -118.322458    Thursday
# 44906 -118.323634   Wednesday
# 78314 -118.321259   Wednesday
# 87553 -118.322450    Thursday

# %%
nearby_coords(df, 33.989412,-118.469024, .01)[df['Location'].str.contains('WINDWARD') 
                        & (df['Day of Week'] =='Tuesday')][['Location', 'Issue time']].sort_values('Issue time')
# Out:
# /home/greg/anaconda3/envs/parking/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                  Location  Issue time
# 58012     46 WINDWARD AVE      1106.0
# 48124  32 WINDWARD AVENUE      1107.0
# 60772     52 WINDWARD AVE      1108.0
# 8345      56 WINDWARD AVE      1109.0
# 75290  54 WINDWARD AVENUE      1110.0
# 7280      64 WINDWARD AVE      1111.0
# 59393     40 WINDWARD AVE      1114.0
# 78686   46 WINDWARD AVE E      1117.0
# 42351     66 WINDWARD AVE      1118.0
# 22779     36 WINDWARD AVE      1132.0
# 16726     56 WINDWARD AVE      1138.0
# 82458   20 WINDWARD AVE E      1139.0
# 6525      66 WINDWARD AVE      1200.0
# 0        309 WINDWARD AVE      1205.0
# 68162    311 WINDWARD AVE      1217.0
# 20207    325 WINDWARD AVE      1231.0
# 61838  40 WINDWARD AVENUE      1242.0
