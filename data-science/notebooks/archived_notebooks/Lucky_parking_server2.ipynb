# %%
import sqlalchemy
import numpy as np
import pandas as pd
import geopandas as gpd
import pickle
from sqlalchemy import *

# %%
sqlalchemy.__version__
# Out:
# '1.3.19'

# %%
from sqlalchemy import create_engine
engine = create_engine('')

# %%
# Opening pickle file
with open( "lucky_parking.p", "rb" ) as f:
  df = pickle.load(f)

# %%
df.to_csv('big_data_lucky_parking.csv')

# %%
del df

# %%
df.head()
# Out:
#    Ticket number Meter Id  Marked Time RP State Plate  Plate Expiry Date  VIN  \
# 2     1104803000      NaN          NaN             CA           201503.0  NaN
# 3     1104820732      NaN          NaN             CA                NaN  NaN
# 33    1108321723      NaN          NaN             CA           201610.0  NaN
# 42    1109139006      NaN          NaN             CA           201608.0  NaN
# 43    1109455266      NaN          NaN             NY                NaN  NaN
#
#     Make Body Style Color            Location  ... Violation Description  \
# 2   NISS         PA    BK       200 WORLD WAY  ...            WHITE CURB
# 3   ACUR         PA    WH       100 WORLD WAY  ...                17104h
# 33  HOND         PA    BK      10635 FRIAR ST  ...              RED ZONE
# 42  HOND        NaN    GO  14006 RIVERSIDE DR  ...     HANDICAP/NO DP ID
# 43  TOYO         PA    WH      3200 CANYON DR  ...       PK IN PROH AREA
#
#     Fine amount   Latitude   Longitude  Agency Description  Color Description  \
# 2          58.0  33.945212 -118.401151                 NaN                NaN
# 3           NaN  33.945212 -118.401009                 NaN                NaN
# 33         93.0  34.185788 -118.363082                 NaN                NaN
# 42        363.0  34.157607 -118.438092                 NaN                NaN
# 43         68.0  34.126932 -118.311225                 NaN                NaN
#
#     Body Style Description            Datetime Plate Expiry Date Parsed  \
# 2                      NaN 2015-12-21 20:55:00               2015-03-01
# 3                      NaN 2015-12-26 15:15:00                      NaT
# 33                     NaN 2015-12-21 10:41:00               2016-10-01
# 42                     NaN 2015-12-19 15:50:00               2016-08-01
# 43                     NaN 2015-12-26 18:15:00                      NaT
#
#    days_expired
# 2         295.0
# 3           NaN
# 33       -285.0
# 42       -226.0
# 43          NaN
#
# [5 rows x 23 columns]

# %%
reader = pd.read_csv('big_data_lucky_parking.csv', chunksize=1000)

# %%
for chunk in reader:
    # For the geometry column, we will use GeoAlchemy's type 'Geometry'
    chunk.drop(["Unnamed: 0",'Ticket number'], axis=1).to_sql('citations', engine, if_exists='append', index=False, 
                          dtype={'Datetime': DateTime,
                            'Fine_amount':Numeric, 
                            'Latitude':Float,
                            'Longitude': Float,
                            })
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# DatabaseError: SSL SYSCALL error: Connection timed out
#
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/pandas/io/sql.py in run_transaction(self)
#    1080             if hasattr(tx, "execute"):
# -> 1081                 yield tx
#    1082             else:
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1129             compiled_sql,
# -> 1130             distilled_params,
#    1131         )
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1316             self._handle_dbapi_exception(
# -> 1317                 e, statement, parameters, cursor, context
#    1318             )
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1510                 util.raise_(
# -> 1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                     self.dialect.do_executemany(
# -> 1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# DatabaseError: (psycopg2.DatabaseError) SSL SYSCALL error: Connection timed out
#
# [SQL: INSERT INTO citations ("Meter Id", "Marked Time", "RP State Plate", "Plate Expiry Date", "VIN", "Make", "Body Style", "Color", "Location", "Route", "Agency", "Violation code", "Violation Description", "Fine amount", "Latitude", "Longitude", "Agency Description", "Color Description", "Body Style Description", "Datetime", "Plate Expiry Date Parsed", days_expired) VALUES (%(Meter Id)s, %(Marked Time)s, %(RP State Plate)s, %(Plate Expiry Date)s, %(VIN)s, %(Make)s, %(Body Style)s, %(Color)s, %(Location)s, %(Route)s, %(Agency)s, %(Violation code)s, %(Violation Description)s, %(Fine amount)s, %(Latitude)s, %(Longitude)s, %(Agency Description)s, %(Color Description)s, %(Body Style Description)s, %(Datetime)s, %(Plate Expiry Date Parsed)s, %(days_expired)s)]
# [parameters: ({'Meter Id': None, 'Marked Time': None, 'RP State Plate': 'CA', 'Plate Expiry Date': 201612.0, 'VIN': None, 'Make': 'CHEV', 'Body Style': 'PA', 'Color': 'WT', 'Location': '1847 47TH ST W', 'Route': '00500', 'Agency': 55.0, 'Violation code': '80.69BS', 'Violation Description': 'NO PARK/STREET CLEAN', 'Fine amount': 73.0, 'Latitude': 34.00099324994452, 'Longitude': -118.31250018076376, 'Agency Description': None, 'Color Description': None, 'Body Style Description': None, 'Datetime': '2017-01-04 13:08:00', 'Plate Expiry Date Parsed': '2016-12-01 00:00:00', 'days_expired': 34.0}, {'Meter Id': None, 'Marked Time': None, 'RP State Plate': 'CA', 'Plate Expiry Date': 201708.0, 'VIN': None, 'Make': 'HOND', 'Body Style': 'PA', 'Color': 'GY', 'Location': '1841 49TH ST W', 'Route': '00500', 'Agency': 55.0, 'Violation code': '80.69BS', 'Violation Description': 'NO PARK/STREET CLEAN', 'Fine amount': 73.0, 'Latitude': 33.99900973647975, 'Longitude': -118.31235054856924, 'Agency Description': None, 'Color Description': None, 'Body Style Description': None, 'Datetime': '2017-01-04 13:16:00', 'Plate Expiry Date Parsed': '2017-08-01 00:00:00', 'days_expired': -209.0}, {'Meter Id': None, 'Marked Time': None, 'RP State Plate': 'CA', 'Plate Expiry Date': 201702.0, 'VIN': None, 'Make': 'TOYT', 'Body Style': 'PA', 'Color': 'GY', 'Location': '1801 49TH ST W', 'Route': '00500', 'Agency': 55.0, 'Violation code': '80.69BS', 'Violation Description': 'NO PARK/STREET CLEAN', 'Fine amount': 73.0, 'Latitude': 33.99901299573424, 'Longitude': -118.31133299790828, 'Agency Description': None, 'Color Description': None, 'Body Style Description': None, 'Datetime': '2017-01-04 13:18:00', 'Plate Expiry Date Parsed': '2017-02-01 00:00:00', 'days_expired': -28.0}, {'Meter Id': None, 'Marked Time': None, 'RP State Plate': 'CA', 'Plate Expiry Date': 201701.0, 'VIN': None, 'Make': 'HYUN', 'Body Style': 'PA', 'Color': 'GY', 'Location': '5000 ST ANDREWS PL S', 'Route': '00500', 'Agency': 55.0, 'Violation code': '80.69BS', 'Violation Description': 'NO PARK/STREET CLEAN', 'Fine amount': 73.0, 'Latitude': 33.99798199880076, 'Longitude': -118.31133399951534, 'Agency Description': None, 'Color Description': None, 'Body Style Description': None, 'Datetime': '2017-01-04 13:20:00', 'Plate Expiry Date Parsed': '2017-01-01 00:00:00', 'days_expired': 3.0}, {'Meter Id': None, 'Marked Time': None, 'RP State Plate': 'CA', 'Plate Expiry Date': 201611.0, 'VIN': None, 'Make': 'NISS', 'Body Style': 'PA', 'Color': 'RD', 'Location': '5000 ST ANDREWS PL S', 'Route': '00500', 'Agency': 55.0, 'Violation code': '80.69BS', 'Violation Description': 'NO PARK/STREET CLEAN', 'Fine amount': 73.0, 'Latitude': 33.99798199880076, 'Longitude': -118.31133399951534, 'Agency Description': None, 'Color Description': None, 'Body Style Description': None, 'Datetime': '2017-01-04 13:21:00', 'Plate Expiry Date Parsed': '2016-11-01 00:00:00', 'days_expired': 64.0}, {'Meter Id': None, 'Marked Time': None, 'RP State Plate': 'CA', 'Plate Expiry Date': 201611.0, 'VIN': None, 'Make': 'NISS', 'Body Style': 'PA', 'Color': 'RD', 'Location': '5000 ST ANDREWS PL S', 'Route': '00500', 'Agency': 55.0, 'Violation code': '5204A-', 'Violation Description': 'DISPLAY OF TABS', 'Fine amount': 25.0, 'Latitude': 33.99798199880076, 'Longitude': -118.31133399951534, 'Agency Description': None, 'Color Description': None, 'Body Style Description': None, 'Datetime': '2017-01-04 13:22:00', 'Plate Expiry Date Parsed': '2016-11-01 00:00:00', 'days_expired': 64.0}, {'Meter Id': None, 'Marked Time': None, 'RP State Plate': 'CA', 'Plate Expiry Date': 201611.0, 'VIN': None, 'Make': 'TOYT', 'Body Style': 'PA', 'Color': 'GN', 'Location': '5000 ST ANDREWS PL S', 'Route': '00500', 'Agency': 55.0, 'Violation code': '80.69BS', 'Violation Description': 'NO PARK/STREET CLEAN', 'Fine amount': 73.0, 'Latitude': 33.99798199880076, 'Longitude': -118.31133399951534, 'Agency Description': None, 'Color Description': None, 'Body Style Description':  ...
# (Background on this error at: http://sqlalche.me/e/13/4xp6)
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _rollback_impl(self)
#     748             try:
# --> 749                 self.engine.dialect.do_rollback(self.connection)
#     750             except BaseException as e:
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_rollback(self, dbapi_connection)
#     542     def do_rollback(self, dbapi_connection):
# --> 543         dbapi_connection.rollback()
#     544
#
# OperationalError: SSL SYSCALL error: EOF detected
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-17-226233b5e91b> in <module>
#       5                             'Fine_amount':Numeric,
#       6                             'Latitude':Float,
# ----> 7                             'Longitude': Float,
#       8                             })
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~/anaconda3/envs/parking/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/pandas/io/sql.py in run_transaction(self)
#    1081                 yield tx
#    1082             else:
# -> 1083                 yield self.connectable
#    1084
#    1085     def execute(self, *args, **kwargs):
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/sqlalchemy/engine/base.py in __exit__(self, type_, value, traceback)
#    2108         def __exit__(self, type_, value, traceback):
#    2109             if type_ is not None:
# -> 2110                 self.transaction.rollback()
#    2111             else:
#    2112                 self.transaction.commit()
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/sqlalchemy/engine/base.py in rollback(self)
#    1751         """
#    1752         if self._parent.is_active:
# -> 1753             self._do_rollback()
#    1754             self.is_active = False
#    1755
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _do_rollback(self)
#    1789     def _do_rollback(self):
#    1790         if self.is_active:
# -> 1791             self.connection._rollback_impl()
#    1792
#    1793     def _do_commit(self):
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _rollback_impl(self)
#     749                 self.engine.dialect.do_rollback(self.connection)
#     750             except BaseException as e:
# --> 751                 self._handle_dbapi_exception(e, None, None, None, None)
#     752             finally:
#     753                 if (
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509             elif should_wrap:
#    1510                 util.raise_(
# -> 1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#    1513             else:
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _rollback_impl(self)
#     747                 self.engine.logger.info("ROLLBACK")
#     748             try:
# --> 749                 self.engine.dialect.do_rollback(self.connection)
#     750             except BaseException as e:
#     751                 self._handle_dbapi_exception(e, None, None, None, None)
#
# ~/anaconda3/envs/parking/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_rollback(self, dbapi_connection)
#     541
#     542     def do_rollback(self, dbapi_connection):
# --> 543         dbapi_connection.rollback()
#     544
#     545     def do_commit(self, dbapi_connection):
#
# OperationalError: (psycopg2.OperationalError) SSL SYSCALL error: EOF detected
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
# Imports



# df = gpd.read_file('sample_data.geojson')
# df['geometry'] = df['geometry'].apply(lambda x: WKTElement(x.wkt, srid=4326))
# df.drop('ticket_number', axis=1, inplace=True)

# For the geometry column, we will use GeoAlchemy's type 'Geometry'
df.drop('Ticket number', axis=1).to_sql('citations', engine, if_exists='replace', index=False, 
                      dtype={'Datetime': DateTime,
                        'Fine_amount':Numeric, 
                        'Latitude':Float,
                        'Longitude': Float,
                        'Plate Expiry Date': Date
                        })
